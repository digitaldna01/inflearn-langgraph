# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from typing_extensions import List, TypedDict
from langgraph.graph import StateGraph

class AgentState(TypedDict):
    query: str
    context: list
    answer: str 
    
graph_builder = StateGraph(AgentState)

# %%
from langchain_tavily import TavilySearch

tavily_search_tool = TavilySearch(
    max_results=3,
    topic="general",
    include_answer=True,
    include_raw_content=True,
    include_images=True,
)

def web_search(state: AgentState):
    query = state['query']
    search_results = tavily_search_tool.invoke(query)
    return {'context': search_results}

# %%
from langsmith import Client
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

client = Client()
generate_prompt = client.pull_prompt("rlm/rag-prompt")
generate_llm = ChatOpenAI(model='gpt-4o')

def web_generate(state: AgentState):
    query = state['query']
    context = state['context']
    
    # 작업 체인을 생성합니다: 먼저 프롬프트를 검색하고, 그 다음 응답을 생성합니다
    # prompt를 llm에게 주입
    rag_chain = generate_prompt | generate_llm | StrOutputParser()
    
    # 쿼리와 컨텍스트로 체인을 호출하여 응답을 얻습니다
    response = rag_chain.invoke({'question': query, 'context': context})
    
    # 생성된 답변을 반환합니다
    return {'answer' : response }

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

basic_llm = ChatOpenAI(model='gpt-4o-mini') 

def basic_generate(state: AgentState):
    query = state['query'] 
    basic_llm_chain = basic_llm | StrOutputParser()
    llm_reponse = basic_llm_chain.invoke(query)
    return {'answer' : llm_reponse}

# %%
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from typing import Literal

class Route(BaseModel):
    target: Literal['vector_store', 'llm', 'web_search'] = Field(
        description="The target for the query to answer"
    )
    
router_system_prompt = """
You are an expert at routing a user's question to 'vector_store', 'llm', or 'web_search'.
'vector_store' contains information about income tax up to December 2024.
if you think the question is simple enough use 'llm'
if you think you need to search the web to answer the question use 'web_search'
"""

router_prompt = ChatPromptTemplate.from_messages([ 
    ("system", router_system_prompt),
    ("human", '{query}'),
])

router_llm = ChatOpenAI(model='gpt-4o-mini')
structured_router_llm = router_llm.with_structured_output(Route)

def router(state: AgentState):
    query = state['query']
    router_chain = router_prompt | structured_router_llm 
    route = router_chain.invoke({'query' : query})
    print(f'router route == {route}')
    print(f'router target == {route.target}')
    return route.target

# %%
from income_tax_graph import graph as income_tax_subgraph

graph_builder.add_node('income_tax_agent', income_tax_subgraph)
graph_builder.add_node('router', router)
graph_builder.add_node('web_generate', web_generate)
graph_builder.add_node('web_search', web_search)
graph_builder.add_node('basic_generate', basic_generate)

# %%
from langgraph.graph import START, END

graph_builder.add_conditional_edges(
    START,
    router,
    {
        'vector_store': 'income_tax_agent',
        'llm': 'basic_generate',
        'web_search': 'web_search',
    }
)

graph_builder.add_edge('web_search', 'web_generate')
graph_builder.add_edge('web_generate', END)
graph_builder.add_edge('basic_generate', END)
graph_builder.add_edge('income_tax_agent', END)

# %%
graph = graph_builder.compile()

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state: AgentState = {
    'query': '연봉 5천만원인 거주자의 소득세는 얼마인가요?',
    'context': [],
    'answer': ''
}
graph.invoke(initial_state)
# Out:
# router route == target='vector_store'
# router target == vector_store
# {'query': '연봉 5천만원인 거주자의 소득세는 얼마인가요?',
#  'context': [Document(id='ca8cc959-002b-4112-88e0-1a43e98fa778', metadata={'source': './Documents/income_tax.txt'}, page_content='② 제70조제1항, 제70조의2에 따른 제74조에 따라 차례로 할 것이 제70조제1항제2호에 따르며 서류를 제출하여야 한다는 경우에는 기준소득 중 거주자 본인이 된다(분산)과 제70조제2와 제74조에 따른 제료 및 제대법을 포함한다. 단, 차별제표청정인 그 업체를 남겨 제출한 경우로 그에 대하여 아니하다.<개정 2013. 1. 1.>\n  ③ 제80조에 따른 수익과 관련의 경우에는 기초공제 중 거주자 본인이 된다(분산)과 그에 관한 적지사항을 분명히 한다.\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제54조의2(공동사업에 대한 소득공제 등 특례) 제51조의3 또는 「조세특례제한법」에 따른 소득공제를 적용하거나 제59조의2에 따른 세액감면을 적용하는 경우 제54조제3항에 따라 공동사업자의 소득에 합산과세되는 특별세액거래의 지출․납입․투자 등의 금액이 있을 경우 주된 공동사업자의 소득에 합산과세되는 소득금액에 합산되어 주된 공동사업자의 합산과세세액은 공동사업소득액 또는 공동사업창출세액을 계산할 때 소득공제 또는 세액공제를 받을 수 있다. \n[개정 2014. 1. 1.]\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제2절 세액의 계산 <개정 2009. 12. 31.>\n제1관 세율 <개정 2009. 12. 31.>\n제55조(세율) 거주자의 종합소득에 대한 소득세는 해당 연도의 종합소득과세표준에 다음의 세율을 적용하여 계산한 금액(이하 "종합소득과세표준세액"이라 한다)을 그 세액으로 한다. <개정 2014. 1. 1., 2016. 12. 20., 2017. 12. 19., 2020. 12. 29., 2022. 12. 31.>\n종합소득\n┌───────────────┐\n│ 과세표준의 6개 구간 │\n├───────────────┤\n│ 1,400만원 이하        │ 84만원 + (1,400만원을 초과하는 금액의 15%)  │\n│ 1,400만원 초과        │ 84만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 8,800만원 이하        │ 624만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 8,800만원 초과        │ 1,536만원 + (8,800만원을 초과하는 금액의 35%)  │\n│ 1.5억원 초과          │ 4,046만원 + (1,500만원을 초과하는 금액의 38%)  │\n│ 3억원 초과            │ 6,460만원 + (3억원을 초과하는 금액의 40%)  │\n│ 5억원 초과            │ 14,760만원 + (5억원을 초과하는 금액의 42%)  │\n│ 10억원 초과           │ 38,406만원 + (10억원을 초과하는 금액의 45%)  │\n└───────────────┘\n② 거주자의 퇴직소득에 대한 소득세는 다음 각 호의 순서에 따라 계산한 금액(이하 ‘퇴직소득 산출세액’이라 한다)으로 한다. <개정 2013. 1. 1., 2014. 12. 23.>'),
#   Document(id='dcfb65e8-2f46-49ec-8d31-2f3be022b375', metadata={'source': './Documents/income_tax.txt'}, page_content='5년 이하: 30만원 → 납입연수\n5년 초과 10년 이하: 150만원 + 50만원 × (납입연수 - 5년)\n10년 초과 20년 이하: 400만원 + 80만원 × (납입연수 - 10년)\n20년 초과: 1,200만원 + 120만원 × (납입연수 - 20년)\n\n② 직장근로자 초과관세환급금을 분배하여 지급받는 경우 세액의 계산 방법 등 필요한 사항은 대통령령으로 정한다. \n<대통령 2014. 12. 23.>\n<전문개정 2009. 12. 31.>\n제64조(부동산매매업자에 대한 세액 계산의 특례)\n1) 대통령령으로 정하는 부동산매매업(이하 “부동산매매업”이라 한다)을 영위하는 거주자가 이하 “부동산매매업자”라 한다)로서 종합소득세법에 제104조제1항제1호(본항을 포함한다) 및 제103조 또는 같은 조 제7항 각 호의 어느 하나에 해당하는 자산의 매매자익(이하 “주택등매매차익”이라 한다)이 있는 자의 종합소득 산출세액은 다음 각 호의 세액 중 많은 것으로 한다. \n<개정 2014. 12. 23., 2017. 12. 19., 2020. 12. 29.>\n1. 종합소득 산출세액\n\n다음 각 목에 따른 세액의 합계액\n  가. 주택등매매차익에 따른 세율을 적용하여 산출한 세액의 합계액\n  나. 종합소득세법 제55조에 따라 주택등매매차익에 대한 개별세액을 공제한 금액을 과세표준으로 하고 이에 제55조에 따른 세율을 적용하여 산출세액'),
#   Document(id='f5135fd8-3df0-4197-8cf4-40c6b4dbee52', metadata={'source': './Documents/income_tax.txt'}, page_content='근무기한: 개월 수로 계산한다. 이 경우 1개월 미만의 기간이 있는 경우에는 이를 1개월로 본다.\n종합소득: 봉급ㆍ상여 등 제20조제1항제1호 및 제23조에 따른 포괄소득(제12조전단에 따른 비과세소득은 제외한다)을 한다.\n⑤ 삭제<2013. 1. 1.>\n⑥ 퇴직소득의 범위 및 계산방법과 그 밖에 필요한 사항은 대통령령으로 정한다.<전문개정 2009. 12. 31.>\n\n제23조 <삭제 2006. 12. 30.>\n제3절 소득금액의 계산\n제5장 2009. 12. 31.>\n제1항 총수입금액 <개정 2009. 12. 31.>\n제24조(총수입금액의 계산) ① 거주자 각 소득에 대한 총수입액(총급여액과 총연금액을 포함한다. 이하 같다)은 해당 과세기간에 수입하였거나 수입할 금액의 합계액으로 한다.\n② 제1항의 경우 금지 외의 자원을 수입할 때는 그 수입금액을 그 거래 당시의 가격에 의하여 계산한다.\n총수입액을 계산할 때 수입하였거나 수입할 금액의 범위와 계산에 관한 필요한 사항은 대통령령으로 정한다.<전문개정 2009. 12. 31.>\n제25조(총수입금액의 계산과 특례) ① 거주자가 부동산 또는 그 부동산상의 권리 등을 대여하거나 보증금ㆍ전세금 또는 이와 유사한 성질의 금액(이하 "보증금"이라 한다)을 받는 경우에는 대통령령으로 정하는 범에 따라 계산한 금액을 상속소득금액에산입할 때 총수입금액에 산입한다. 다만, 주택자금의 용도로 보이는 명저 1조(F) 또는 1세대당 3천미터 이하인 주택으로서 해당 세기기간이 기준시가가 2억인 이하 주택을 2026년 12월 31일까지 주택 수입 계산하지 아니하는 대여요금받는 경우에는 다음 중 하나의 하나에 해당하는 경우를 하며, 주택 수의 계산에 필요한 사항은 대통령령으로 정한다. <개정 2012. 1. 1., 2014. 1. 1., 2016. 12. 20, 2018. 12. 31, 2021. 12. 8, 2023. 12. 31.>\n\n3주택 이상을 소유하며 해당 주택의 보증금의 합계액이 3억원을 초과하는 경우  \n주택당(해당 주택의 기준시가가 12억원 이하인 주택 주택에 포함하지 아니하는 것을 소유하거나 해당 주택의 보증금의 합계액이 3억원 이상인 경우로서 대통령령으로 정하는 금액을 초과하는 경우\n거주자가 재산소득(資産所得) 또는 임금을 가사로 소비하지증명된 날에 지급받는 경우에 이를 소비하지 않고 사용하는 금액에 대해 가액에 해당하는 금액을 소비하지 않으면 소득금액에 대한 선입법의 사업소득금액에 산입한다.<삭제 2021. 12. 19.>\n[시행일: 2026. 1. 1. <지방소득세법 제25조제1항제1호>]')],
#  'answer': '연봉 5천만 원의 거주자의 소득세는 624만 원입니다. 이는 5천만 원을 초과하는 금액에 대해 추가 세율이 적용되지 않아, 표준 세율의 적용만으로 계산된 결과입니다.'}

# %%
initial_state: AgentState = {
    'query': '역삼역 맛집 추천해주세요',
    'context': [],
    'answer': ''
}
graph.invoke(initial_state)
# Out:
# router route == target='web_search'
# router target == web_search
# {'query': '역삼역 맛집 추천해주세요',
#  'context': {'query': '역삼역 맛집 추천해주세요',
#   'follow_up_questions': None,
#   'answer': '역삼역 맛집 추천으로 신동궁 감자탕과 떡도리탕이 유명하며, 지아니스나폴리 역삼 본점도 인기가 많습니다.',
#   'images': ['https://mblogthumb-phinf.pstatic.net/MjAyNDEwMTVfMjgz/MDAxNzI4OTc1MzQ0MTA0.b7OoL30rv8ZXcoNCCwHGoNcww1BvlkoYor6ZNdO36pcg.yIE47UUiIP5lyQ6mHrsX_zMVEZGV6J5oZ5WPddvLdPwg.JPEG/%EC%A0%9C%EB%AA%A9%EC%9D%84_%EC%9E%85%EB%A0%A5%ED%95%B4%EC%A3%BC%EC%84%B8%EC%9A%94_-004_(2).jpg?type=w800',
#    'https://blog.kakaocdn.net/dna/AQUTn/btrXJgc8LC6/AAAAAAAAAAAAAAAAAAAAAPKvBQWDH_JtNsy3DiV4XGVXRYXp3gRHNqdBycDfd2T0/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1777561199&allow_ip=&allow_referer=&signature=1LnevIQ1%2FzhjYeHB6m%2B3EvQuaWI%3D',
#    'https://blog.kakaocdn.net/dna/v3E8d/btrXInw3tD0/AAAAAAAAAAAAAAAAAAAAAGj_y_g2LD7NxPy-OYPjfGEvW5vQxH0JPZHBTQv86vQH/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1777561199&allow_ip=&allow_referer=&signature=FruOxtxsm%2Bf9GubAO2qYn%2F1%2Bm8g%3D',
#    'https://mblogthumb-phinf.pstatic.net/MjAyNjAyMDNfMTAz/MDAxNzcwMTIwMzU0NjE5.ChrwIRCwBqmulLIImBKGQEC16R1tg8RBOf3H_jflwyMg.hIo1P9IpSm-aFHmmHBI95l5tMe6UBzW10ku961SHJxYg.JPEG/SE-12ABE294-B7D3-4E05-8C3F-9FBA95BB9D42.jpg?type=w800',
#    'https://img.siksinhot.com/place/1676255404281522.jpg?w=560&h=448&c=Y'],
#   'results': [{'url': 'https://jdblue2022.tistory.com/entry/%EC%97%AD%EC%82%BC%EC%97%AD-%EB%A7%9B%EC%A7%91-%EB%B2%A0%EC%8A%A4%ED%8A%B810',
#     'title': '역삼역 맛집 베스트10 추천 2024 플레이스 맛집',
#     'content': '# 역삼역 맛집 베스트10 추천 2024 플레이스 맛집. 오늘은 강남의 중심인 역삼역 근처의 맛집 베스트 10곳을 소개해드리고자 하는데\xa0양대 포털의\xa0플레이스를 중심으로 순위를 취합하여 역삼역 로컬 맛집들과 함께 여러 음식점을\xa0묶어서 역삼\xa0맛집을 정리해드리고자 합니다. 기본적인 맛집 선정 기준은 양대 검색 포털인 네이버(50%)를 비롯해 구글(50%)의 플레이스 순위를 반영하여 선정하였습니다. 역삼역 맛집 베스트10 음식점 주요 메뉴. **포털 기준 - 네이버(핫플 반영) / 구글(현지인 가성비 맛집)**. 1. 지아니스나폴리 역삼 본점(네이버 8위, 구글 3위). 2. 이도곰탕(네이버 12위, 구글 6위). 지아니스나폴리 역삼 본점 플레이스(구글 평점 4.3). 가장 먼저 소개해드릴 역삼역 맛집은 역삼역 7번 출구 근처에 위치하고 있는 이탈리아 레스토랑 지아니스나폴리 역삼 본점입니다. 역삼역 이도곰탕 플레이스(구글 평점 4.2). 이어지는 역삼역 맛집은 역삼역 8번 출구 근처에 위치하고 있는 한우곰탕 전문점 이도곰탕 본점입니다. 역삼역 대우부대찌개 플레이스(구글 평점 4.2). 이어지는 역삼역 맛집은 역삼역 6번 출구 근처에 위치하고 있는 부대찌개 전문점 대우부대찌개입니다. 역삼역 호보식당 플레이스(구글 평점 4.4). 역삼역 옛날농장 플레이스(구글 평점 4.0). 역삼역 고갯마루 플레이스(구글 평점 4.2). 역삼역 보슬보슬 플레이스(구글 평점 4.1). 역삼역 서울집 플레이스(구글 평점 4.2).',
#     'score': 0.90039873,
img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1777561199&allow_ip=&allow_referer=&signature=Uo%2FPu%2FJsLUZPSOIPtQcjqppJVxg%3D',
#      'https://blog.kakaocdn.net/dna/byC6uG/btsJ75crBae/AAAAAAAAAAAAAAAAAAAAANwH71pwB-m9MUK6WmZM6BuS2FiALHhnXD5xUeN3cvE3/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1777561199&allow_ip=&allow_referer=&signature=b64mYGAuFd3R3G%2FxdH98DEvq6qA%3D',
#      'https://blog.kakaocdn.net/dna/cABpOI/btsJ7OahCHa/AAAAAAAAAAAAAAAAAAAAAAPt3OVyrp1V2srYyAKBqePnPFSas0Yk5xsqlfY8PZbL/img.png?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1777561199&allow_ip=&allow_referer=&signature=5CXtgMouQyviretFQjYp75jlNbk%3D',
#      'https://i1.daumcdn.net/thumb/C176x120/?fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FqP4kU%2FbtsKbFSwnas%2FAAAAAAAAAAAAAAAAAAAAALnD6eexXQHRT7i6d7qCyUBzilr-_3eYU7Oarp8ZQtf6%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1777561199%26allow_ip%3D%26allow_referer%3D%26signature%3DQJdDCPHwbqXtiL2IKqUn4QxdMyE%253D',
#      'https://i1.daumcdn.net/thumb/C176x120/?fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FbNhDaF%2FbtsJ91HqKt1%2FAAAAAAAAAAAAAAAAAAAAAGZ6TeH6D1CBobkoO7Y68646hslN4pToc0x01hxNx2r0%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1777561199%26allow_ip%3D%26allow_referer%3D%26signature%3DhARx%252BMy0LqskJDqb5LSH982kyow%253D',
#      'https://i1.daumcdn.net/thumb/C176x120/?fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FNUoIX%2FbtsJ4rsl3YE%2FAAAAAAAAAAAAAAAAAAAAADeNRqtd6E_Ib7owYdZQS8PIEK4t8L_yBx5a_OtGTzYn%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1777561199%26allow_ip%3D%26allow_referer%3D%26signature%3DV4CHpXM7xCr2AVvQewp%252FCLvZRSU%253D',
#      'https://i1.daumcdn.net/thumb/C176x120/?fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FuuCOQ%2FbtsJUOHjNI4%2FAAAAAAAAAAAAAAAAAAAAAJ4y2yLd0P7wpag9m2esy2C_kMV65dfyK2SgOLbj0hU5%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1777561199%26allow_ip%3D%26allow_referer%3D%26signature%3D6P1eJjWTzFq9I3NPrHgAqWStxEk%253D',
#      'https://tistory1.daumcdn.net/tistory/5352448/attach/9a6a5cf7b2274871a457e5446ba67fe4']},
#    {'url': 'https://www.siksinhot.com/taste?upHpAreaId=9&hpAreaId=1122&isBestOrd=N',
#     'title': '서울 강남맛집 - 역삼역맛집 추천 베스트10 | 식신 맛집추천',
#     'content': '# 역삼역 맛집 (249곳) - 식신 지역맛집. 냉 메밀국수 & 한우 차돌박이, 디너 맡김차림, 런치 맡김차림, 비빔 메밀국수 & 한우 차돌박이, 셰프 특선 맡김차림, 오마카세 라이트, 우브리앙 한우 도가니탕, 프로포즈 패키지, 한우 갈비살 정식, 한우 양념 갈비살 정식, 한우 얼큰 소고기탕, 한우명품모둠구이 2인 400g, 한우명품모둠구이 3인 600g, 한우명품모둠구이 4인 800g, 해피아워 맡김차림. 광어 시가롤(2pcs), 런치) 후무스 플레이트, 런치)비키니 샌드위치, 벽돌치킨, 비프 타르타르, 에피스 스테이크, 전복 리조또, 초리조 라구, 트러플 파스타. 3단 브런치, 그린페스토 파스타, 꼬막 오일 파스타, 디너 4코스, 볼로네제 파스타, 부라타 치즈, 새우 리조또, 아이스크림, 알리오올리오, 연어 세비체, 이베리코 스테이크, 채끝 스테이크, 치즈케이크, 치킨 크림 리조또, 프렌치 토스트. A506 숙성 삼겹살 150g, D806 숙성 삼겹살 150g, i506 숙성 목살 150g, 계란찜, 김치찌개, 숙성 한우 채끝등심 100g, 영수증 리뷰 참여 시 소주 증정, 저녁 룸차지(룸 이용 금액), 점심 룸차지(룸 이용 금액), 제육쌈밥, 카니보어 하이볼, 크림볶음밥, 트러플 크림볶음밥, 한우 육회 170g, 한우 육회비빔밥, 한우 차돌박이 120g.',
#     'score': 0.8820324,
#     'raw_content': '![twinLogo_link](/static2/images/common/new_twinLogo_pc.png)\n![](/static2/images/common/siksinLogo.svg)\n\n# 역삼역 맛집 (249곳) - 식신 지역맛집\n\n![내 위치 검색 아이콘](/static2/images/common/current_area_icon.png)\n\n## 추천 맛집(249)식신과 매장 방문 고객님들이 함께 엄선한 인기 맛집입니다.\n\n![](https://img.siksinhot.com/place/1646037363521138.jpg?w=560&h=448&c=Y)\n![best](/static2/images/common/ico_best_3.png)\n\n디너 에센셜 코스 메뉴, 디너 테이스팅 코스 메뉴, 런치 테이스팅 코스 메뉴, 런치 테이스팅 코스 메뉴, 디너 테이스팅 코스 메뉴\n\n8901\n\n4\n\n25\n\n![](https://img.siksinhot.com/place/1676255404281522.jpg?w=560&h=448&c=Y)\n![best](/static2/images/common/ico_best_2.png)\n\n등심구이, 등심부대찌개, 부대찌개, 소시지구이, 안심구이\n\n36231\n\n93\n\n179\n\n![](https://img.siksinhot.com/place/1464583908225111.png?w=560&h=448&c=Y)\n![best](/static2/images/common/ico_best_2.png)\n\n고기사리 추가, 명태회무침, 수육, 쌀곰탕면, 쌀면곰탕 특, 장국수, 장죽, 특고기추가, 특곰탕, 한우 곰탕\n\n36133\n\n104\n\n163\n\n![](https://img.siksinhot.com/place/1742173194728208.jpg?w=560&h=448&c=Y)\n![best](/static2/images/common/ico_best_2.png)\n\n오마카세코스\n\n915\n\n0\n\n3\n\n![](https://img.siksinhot.com/place/1696388552549158.jpg?w=560&h=448&c=X)\n![best](/static2/images/common/ico_best_2.png)\n\nDINNER, LUNCH\n\n7595\n\n5\n\n4\n\n![](https://img.siksinhot.com/place/1686718494950616.jpg?w=560&h=448&c=X)\n![best](/static2/images/common/ico_best_2.png)\n\n(시즌메뉴)중식냉면, Dinner A, Dinner B, Dinner C, Dinner D, Dinner E, Lunch A, Lunch B, Lunch C, Lunch D, Special Course, 게살샥스핀스프, 게살유산슬, 마파두부, 모자새우, 불도장, 산라탕, 삼선누룽지탕, 삼선탕스프, 송이샥스핀찜, 송포해삼, 양장피, 오향장육냉채, 전가복, 탕수육, 해삼삼겹살, 해파리장육냉채, 홍보각 특선냉채, 홍소팔진샥스핀찜, 홍소해삼\n\n19419\n\n3\n\n30\n\n![](https://img.siksinhot.com/place/1557475606400114.jpeg?w=560&h=448&c=Y)\n![best](/static2/images/common/ico_best
#     'images': ['https://www.siksinhot.com/logo.png',
#      'https://www.siksinhot.com/static2/images/common/current_area_icon.png',
#      'https://img.siksinhot.com/place/1646037363521138.jpg?w=560&h=448&c=Y',
#      'https://www.siksinhot.com/static2/images/common/ico_best_3.png',
#      'https://img.siksinhot.com/place/1676255404281522.jpg?w=560&h=448&c=Y',
#      'https://www.siksinhot.com/static2/images/common/ico_best_2.png',
#      'https://img.siksinhot.com/place/1464583908225111.png?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1742173194728208.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1696388552549158.jpg?w=560&h=448&c=X',
#      'https://img.siksinhot.com/place/1686718494950616.jpg?w=560&h=448&c=X',
#      'https://img.siksinhot.com/place/1557475606400114.jpeg?w=560&h=448&c=Y',
#      'https://www.siksinhot.com/static2/images/common/ico_best_1.png',
#      'https://img.siksinhot.com/place/1676004161489392.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1623056337289714.PNG?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1641117793950043.PNG?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1686717730829644.jpg?w=560&h=448&c=X',
#      'https://img.siksinhot.com/place/1702352425211404.jpg?w=560&h=448&c=X',
#      'https://img.siksinhot.com/place/1743130630165551.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1676257120536544.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1655455948122692.jpg?w=560&h=448&c=X',
#      'https://img.siksinhot.com/place/1458109170683408.PNG?w=560&h=448&c=Y',
#      'https://www.siksinhot.com/static2/images/common/ico_best_0.png',
#      'https://img.siksinhot.com/place/1378108000137736.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1675995746616305.jpg?w=560&h=448&c=X',
#      'https://img.siksinhot.com/place/1676261270551571.jpg?w=560&h=448&c=Y',
#      'https://www.siksinhot.com/static2/images/common/ico_correct_food00004.png',
#      'https://img.siksinhot.com/place/1499030519272163.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1584431587987268.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1617849265318236.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1554789466101144.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1533097637639238.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1533180566922344.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1525155181848639.png?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1545063746082464.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1704243453852850.jpg?w=560&h=448&c=X',
#      'https://img.siksinhot.com/place/1696471045413289.jpg?w=560&h=448&c=Y',
#      'https://img.siksinhot.com/place/1676257591626506.jpg?w=560&h=448&c=X',
#      'https://www.siksinhot.com/static2/images/map/filter_close_icon.png',
#      'https://www.siksinhot.com/static2/images/common/new_twinLogo_pc.png',
#      'https://www.siksinhot.com/static2/images/common/btn_footer_sns01.gif',
#      'https://www.siksinhot.com/static2/images/common/n_blog.png',
#      'https://www.siksinhot.com/static2/images/common/btn_footer_sns03.gif',
#      'https://www.siksinhot.com/static2/images/common/btn_footer_sns04.gif']},
#    {'url': 'https://hotel-iu.tistory.com/8573',
#     'title': '역삼역 점심 맛집 베스트 추천 top 10',
#     'content': "## 역삼역 점심 맛집 베스트 추천 top 10. 역삼역 점심 맛집 베스트 추천 top 10곳을 소개합니다. | 상호명: 아침점심저녁 강남점  주소: 서울특별시 강남구 역삼동 706-17 지하1층 B102호  전화번호: 미입력  관련 키워드: ['제육계란이불덮밥', '순살닭도리탕', '아구도리탕', '불고기덮밥', '고등어덮밥']  관련 태그: 미입력  영업시간: 미입력 |. | **2: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문** |. | 상호명: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문  주소: 서울특별시 강남구 역삼동 702-13 성지하이츠1 오피스텔 지하1층 107호  전화번호: 미입력  관련 키워드: ['선릉역부대찌개', '강남점심식당', '선릉역점심', '역삼역직장인저녁', '선릉역밥집']  관련 태그: ['데이트하기 좋은', '젊고 캐쥬얼한', '모임하기 좋은']  영업시간: 평일 11:00~15:00 | 평일 17:00~20:00 |. | 상호명: 온심옥 역삼본점  주소: 서울특별시 강남구 역삼동 640-23 1층 온심옥 역삼본점  전화번호: 미입력  관련 키워드: ['회식', '직장인', '가족외식장소', '점심', '서울한식']  관련 태그: ['데이트하기 좋은', '단체회식', '젊고 캐쥬얼한']  영업시간: 매일 11:00~21:30 마지막 주문 21:00 | 일요일 휴무 |. | 상호명: 고래불 역삼본점  주소: 서울특별시 강남구 역삼동 828-52 백악빌딩 1, 2층 고래불  전화번호: 미입력  관련 키워드: ['강남역대방어코스요리', '역삼역상견례룸식당', '콜키지프리', '강남역가족점심모임', '역삼역파인다이닝']  관련 태그: ['모임하기 좋은', '특별한 날', '단체회식']  영업시간: 평일 11:30~14:30 | 평일 17:00~22:00 | 주말 11:30~22:00 |.",
#     'score': 0.87706697,
#     'raw_content': '# [초코초코 해피라이프](https://hotel-iu.tistory.com/ "초코초코 해피라이프")\n\n추천 TOP 10\n\n## 역삼역 점심 맛집 베스트 추천 top 10\n\n초코초코 코니코니 2025. 2. 27. 20:24\n\n반응형\n\n#### **역삼역 점심 맛집 베스트 추천 top 10**\n\n---\n\n역삼역 점심 맛집 베스트 추천 top 10곳을 소개합니다.\n\n---\n\n|  |\n| --- |\n| **1: 아침점심저녁 강남점** |\n|  |\n| 상호명: 아침점심저녁 강남점  주소: 서울특별시 강남구 역삼동 706-17 지하1층 B102호  전화번호: 미입력  관련 키워드: [\'제육계란이불덮밥\', \'순살닭도리탕\', \'아구도리탕\', \'불고기덮밥\', \'고등어덮밥\']  관련 태그: 미입력  영업시간: 미입력 |\n| 소개글: 몽글몽글한 계란과 어울리는 재료들의 덮밥과 집밥 생각나는 따뜻한 찌개요리들 배달과 포장을 전문으로 하고있습니다!! |\n| **<https://map.naver.com/p/entry/place/1249578375>** 아침점심저녁 강남점 바로가기▲ |\n\n---\n\n|  |\n| --- |\n| **2: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문** |\n|  |\n| 상호명: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문  주소: 서울특별시 강남구 역삼동 702-13 성지하이츠1 오피스텔 지하1층 107호  전화번호: 미입력  관련 키워드: [\'선릉역부대찌개\', \'강남점심식당\', \'선릉역점심\', \'역삼역직장인저녁\', \'선릉역밥집\']  관련 태그: [\'데이트하기 좋은\', \'젊고 캐쥬얼한\', \'모임하기 좋은\']  영업시간: 평일 11:00~15:00 | 평일 17:00~20:00 |\n| 소개글: 선릉 직장인의 든든한 밥집 빨강우산부대찌개를 소개합니다.  2017년 개업 이래, 빨강우산부대찌개는 선릉역 근처에서 줄서는 식당으로 서서히 입소문을 탄 가게가 되었습니다. 단일 메뉴인 부대찌개 하나만 판매하며 이곳은 맛과 가성비 모두를 만족시키며 많은 이들의 사랑을 받고 있습니다.  1. 9000원의 행복! 밥,라면,느타리버섯,납작당면까지 무한리필!  한 끼를 먹어도 제대로 먹어야 합니다. 선릉 직장인들의 점심,저녁 고민을 덜어 주는 빨강우산 부대찌개에서는 밥,라면,느타리버섯,납작당면을 무한리필로 제공합니다. 한번 먹고 아쉽다면, 마음껏 더 드세요. 속이 든든해야 일도 잘 풀리는 법입니다.  이곳은 행정안전부와 강남구에서 선정한 착한가격 업소입니다. 비싼 강남 한복판에서도 9,000원이면 배부르게 먹을수 있는 곳, 주머니 사정이 팍팍해도 부담없이 따뜻한 한 끼를 즐길수 있는 곳. 그래서 많은 사람들이 찾고, 한 번 온 손님들은 단골이 됩니다.  2. 15년 동안 오직 부대찌개만 연구한 주인장의 정성  빨강우산부대찌개는 15년간 오직 부대찌개만을 연구한 주인장의 손길이 담긴 곳입니다. 한우 사골로 직접 끓이는 육수, 비법 양념이 만나 감칠맛을 냅니다.  이 곳의 부대찌개는 존슨빌 소세지와 후랑크소세지, 스팸, 신선한 채소, 그리고 쫄깃한 라면사리까지 어우러진 깊고 푸짐한 맛과 청양고춧가루가 첨가된 양념의 개운한 맛 덕분에, 해장용으로도, 점심식사와 단체 모임 회식, 가족 식사로도 완벽한 선택이 됩니다.  3. 위생 걱정 없이 즐기는 부대찌개  음식은 맛 뿐만 아니라 안전해야 합니다. 빨강우산부대찌개는 식약처 인증 위생등급 \'매우 우수\'를 받은 식당입니다. 철저한 식재료 관리와 청결한 조리 환경을 유지하며, 언제나 안심하고 즐길 수 있는 공간을 만듭니다.  \\* 주차 안내 성지하이츠1 오피스텔 주차장 이용 가능 주차료 : 10분당 1,200원(변동 가능) 주차비 지원 없음(대중교통 이용 추천) \'모두의 주차장\'앱을 통해 근처 저렴한 유료주차장 검색 가능  선릉역 주변 식당을 찾는다면, 빨강우산 부대찌개를 꼭 방문해 보세요! 선릉 직장인들이 인정하는 부대찌개집으로, 푸짐한 한 끼를 책임지는 곳입니다. 가성비 좋은 식사를 원한다면, 그리고 다양한 재료가 무한리필되는 부대찌개를 즐기고 싶다면 지금 방문해 보세요.  \'\'빨강우산\'\'의 따뜻하고 포근한 품 안에서 시그니처 부대찌개 한 숟가락에 국물의 따스함과 과거와 현대의 맛의 조화를 느껴보세요~ 감사합니다^^  Feel the warmth of the soup and the harmony of the past and modern tastes with a spoonful of signature budaejjigae in the warm and cozy arms of \'Red Umbrella\'~ Thank you ^^ |\n| **<https://map.naver.com/p/entry/place/1559151290>** 빨강우산 부대찌개 선릉역 본점 점심저녁 전문 바로가기▲ |\n\n---\n\n|  |\n| --- |\n| **3: 동화고옥 강남 N타워점** |\n|  |\n| 상호명: 동화고옥 강남 N타워점  주소: 서울특별시 강남구 역삼동 648-9 B2 동화고옥 강남 N타워점  전화번호: 미입력  관련 키워드: [\'강남룸식당\', \'강남점심\', \'강남상견례\', \'강남코스요리\', \'강남한정식\']  관련 태그: 미입력  영업시간: 미입력 |\n| 소개글: Bloom in the Palace, 함께 모여 꽃이 피어나는 집 동화고옥 강남 N타워점에서 인사드립니다.  저희 동화고옥은 고객님들의 많은 사랑을 받아 강남 N타워점에 새롭게 재단장하여 오픈하였습니다. 강남 한정식, 강남역 룸식당 을 찾으시는 고객님께 추천드리며,  강남 N타워 맛집 동화고옥은 우리 음식 문화의 정수라 할 수 있는 \'궁중 음식\'을 현대적으로 전승해 아름다운 우리 식문화를 재현하여 고급스러운 분위기와 맛을 선보이는 매장으로 강남역 상견례 장소로도 추천드립니다.  귀한 성찬, 좋은 벗과 함께하는 정성이 가득한 시간을 뜰 속에서 소중한 가족, 연인과 함께 향기로운 기운을 맞이하세요! |\n| **<https://map.naver.com/p/entry/place/1825366493>** 동화고옥 강남 N타워점 바로가기▲ |\n\n---\n\n|  |\n| --- |\n| **4: 온심옥 역삼본점** |\n|  |\n| 상호명: 온심옥 역삼본점  주소: 서울특별시 강남구 역삼동 640-23 1층 온심옥 역삼본점  전화번호: 미입력  관련 키워드: [\'회식\', \'직장인\', \'가족외식장소\', \'점심\', \'서울한식\']  관련 태그: [\'데이트하기 좋은\', \'단체회식\', \'젊고 캐쥬얼한\']  영업시간: 매일 11:00~21:30 마지막 주문 21:00 | 일요일 휴무 |\n| 소개글: 안녕하세요. 따듯한 마음을 잇는 집 온심옥 입니다..  저희 갈비탕은 필터 3개로 걸러낸 맑은 물만을 사용하여 20시간 이상 푹 끓여 내어, 속이 탁! 풀리는 진한 국물을 선사합니다.  갈비탕은 임금님께서 드시던 최고의 보약 음식으로 코로나로 병원을 자주 다니시는 분들 70세 이상 어르신들도 기력 회복에 큰 도움이 되는 보약입니다. (어르신들에게는 1000원 할인 혜택)  갈비는 최상의 등급 초이스 척갈비를 쓰고 있으며 매우 부드럽고 쫄깃한 식감을!! 속이편한 갈비탕에는 속이 편하게 만들어주는 효과가 있는 우엉을 넣어 육수를 만들어내는 갈비탕은 온심옥 역삼본점에서만 드실 수 있는 갈비탕입니다.  갈비살을 온심옥에만 있는 특제 소스인 초록다데기와 육장소스를 찍어드시거나 탕에 풀어 드시면 어디에서도 드실 수 없는 갈비탕의 새로운 맛을 느끼게 되실 겁니다.  온심옥의 베스트 메뉴는 갈비탕 외에 매운 갈비찜은 맛~있게 매운 양념이 화요+토닉과 최고의 조합을 자랑한답니다! 식사 후 버터와 밥을 비벼 드시거나 깍두기 볶음밥으로 마무리하시면 최고의 식사를 하실 수 있습니다.  한우곱창전골은 일주일 동안 열심히 일하신 분들 동료들과 금요일 저녁 소주 한잔 생각나 실 때 \'온심옥\'에서 한우곱창전골 드시면서 서로 그동안 고민했던 이야기들이 자연스럽게 대화할 수 있는 ...
#     'images': ['https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FbfW1F8%2FbtsMxFvCQRL%2FAAAAAAAAAAAAAAAAAAAAAOd2L2NS6cAixMoNTTD_1IxTCngl0UzbaDkecM-KI5P6%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1780239599%26allow_ip%3D%26allow_referer%3D%26signature%3DyFr58ptDJsU4ZkKJJc%252FwIEFjNsA%253D',
#      'https://tistory1.daumcdn.net/tistory/4349053/attach/3d0219e7e1fd4caf9df6433a3bc3c789']}],
#   'response_time': 5.03,
#   'request_id': 'be4c64bd-6097-4adb-afe5-a6d3a68a7882'},
#  'answer': '역삼역 부근에서 맛집으로 추천할 만한 곳은 신동궁 감자탕과 떡도리탕이 유명한 신동궁 감자탕 역삼직영점, 이탈리아 음식점 지아니스나폴리 역삼 본점이 있습니다. 대우부대찌개와 호보식당, 고갯마루 등도 인기 있는 맛집입니다. 다양한 메뉴와 독특한 분위기의 식당들이 많이 있어 선택의 폭이 넓습니다.'}
